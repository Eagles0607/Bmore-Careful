# %%
import pandas as pd

# %%
url = 'https://data.baltimorecity.gov/resource/4ih5-d5d5.csv? $$app_token=9r9ClJMnHI3HYJN6jhOYHnO8g'

# %%
crimeData = pd.read_csv(url)

# %%
crimeData
# Out:
#      :@computed_region_5kre_ccpb  :@computed_region_gwq4_fjxs  \
# 0                          275.0                        112.0
# 1                          105.0                        253.0
# 2                          124.0                        104.0
# 3                          194.0                          1.0
# 4                          247.0                         83.0
# 5                          141.0                        123.0
# 6                          121.0                        109.0
# 7                          121.0                          6.0
# 8                          169.0                        161.0
# 9                          157.0                         40.0
# 10                          21.0                        102.0
# 11                         197.0                         77.0
# 12                         201.0                          7.0
# 13                         275.0                        195.0
# ...

# %%
crimeData.to_csv('C:\\Users\charles.wiles\Desktop\BmoreCrime.csv')

# %%
crimeDataclean = crimeData[crimeData["description","crimedate","crimetime","district","neighborhood","post","weapon"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\charles.wiles\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5280)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5126)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20523)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20477)()
#
# KeyError: ('description', 'crimedate', 'crimetime', 'district', 'neighborhood', 'post', 'weapon')
#
# ...

# %%
crimeData.head(0)
# Out:
# Empty DataFrame
# Columns: [:@computed_region_5kre_ccpb, :@computed_region_gwq4_fjxs, :@computed_region_s6p5_2pgr, crimecode, crimedate, crimetime, description, district, inside_outside, latitude, location, location_1, location_1_address, location_1_city, location_1_state, location_1_zip, longitude, neighborhood, post, premise, total_incidents, weapon]
# Index: []
#
# [0 rows x 22 columns]
